# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r'C:\Drivers\diabetes.csv')

# %%
data.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
#Scatter plot with Bloodpressure and Glucose
plt.scatter(data['SkinThickness'],data['Glucose'])

#adding title to the plot
plt.title("Scatter plot")

#Setting the x and y labels
plt.xlabel('SkinThickness')
plt.ylabel('Glucose')

#Showing result
plt.show()

# %%
#Line chart with SkinThickness and Glucose
plt.plot(data['SkinThickness'])
plt.plot(data['Glucose'])

#adding title to the plot
plt.title("Line plot")

#Setting the x and y labels
plt.xlabel('SkinThickness')
plt.ylabel('Glucose')

#Showing result
plt.show()

# %%
#Bar chart and Bar plot
plt.bar(data['SkinThickness'],data['Glucose'])

#adding title to the plot
plt.title("Bar plot")

#Setting the x and y labels
plt.xlabel('SkinThickness')
plt.ylabel('Glucose')

#Showing result
plt.show()

# %%
#Histogram
plt.hist(data['Insulin'])

#adding title to the plot
plt.title("Histogram")

#Showing result
plt.show()
